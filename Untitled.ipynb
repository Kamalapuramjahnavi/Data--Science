# %%
import os
import pandas as pd
import numpy as np
from scipy.stats import randint
import seaborn as sns # used for plot interactive graph. 
import matplotlib.pyplot as plt
import seaborn as sns
from io import StringIO
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import chi2
from IPython.display import display
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn import metrics

# %%
df = pd.read_csv("C:/Users/Jahnavi/Desktop/kaiburr project/dataset/complaints.csv")
df.shape
# Out:
# (4078867, 18)

# %% [markdown]
# # Data Analysis

# %%
df.head(3)
# Out:
#   Date received                                            Product  \
# 0    2023-08-25  Credit reporting or other personal consumer re...
# 1    2023-08-25  Credit reporting or other personal consumer re...
# 2    2023-08-25  Credit reporting or other personal consumer re...
#
#         Sub-product                                              Issue  \
# 0  Credit reporting  Problem with a company's investigation into an...
# 1  Credit reporting               Incorrect information on your report
# 2  Credit reporting                        Improper use of your report
#
#                                            Sub-issue  \
# 0  Their investigation did not fix an error on yo...
# 1                Information belongs to someone else
# 2  Credit inquiries on your report that you don't...
#
#   Consumer complaint narrative Company public response        Company State  \
# 0                          NaN                     NaN  EQUIFAX, INC.    PA
# 1                          NaN                     NaN  EQUIFAX, INC.    GA
# 2                          NaN                     NaN  EQUIFAX, INC.    FL
#
#   ZIP code Tags Consumer consent provided? Submitted via Date sent to company  \
# 0    15146  NaN                        NaN           Web           2023-08-26
# 1    30152  NaN                        NaN           Web           2023-08-25
# 2    32137  NaN                      Other           Web           2023-08-25
#
#   Company response to consumer Timely response? Consumer disputed?  \
# 0      Closed with explanation              Yes                NaN
# 1      Closed with explanation              Yes                NaN
# 2      Closed with explanation              Yes                NaN
#
#    Complaint ID
# 0       7560850
# 1       7560851
# 2       7560852

# %%
df.head(3).T
# Out:
#                                                                               0  \
# Date received                                                        2023-08-25
# Product                       Credit reporting or other personal consumer re...
# Sub-product                                                    Credit reporting
# Issue                         Problem with a company's investigation into an...
# Sub-issue                     Their investigation did not fix an error on yo...
# Consumer complaint narrative                                                NaN
# Company public response                                                     NaN
# Company                                                           EQUIFAX, INC.
# State                                                                        PA
# ZIP code                                                                  15146
# Tags                                                                        NaN
# Consumer consent provided?                                                  NaN
# Submitted via                                                               Web
# Date sent to company                                                 2023-08-26
# Company response to consumer                            Closed with explanation
# Timely response?                                                            Yes
# Consumer disputed?                                                          NaN
# Complaint ID                                                            7560850
#
#                                                                               1  \
# Date received                                                        2023-08-25
# Product                       Credit reporting or other personal consumer re...
# Sub-product                                                    Credit reporting
# Issue                                      Incorrect information on your report
# Sub-issue                                   Information belongs to someone else
# Consumer complaint narrative                                                NaN
# Company public response                                                     NaN
# Company                                                           EQUIFAX, INC.
# State                                                                        GA
# ZIP code                                                                  30152
# Tags                                                                        NaN
# Consumer consent provided?                                                  NaN
# Submitted via                                                               Web
# Date sent to company                                                 2023-08-25
# Company response to consumer                            Closed with explanation
# Timely response?                                                            Yes
# Consumer disputed?                                                          NaN
# Complaint ID                                                            7560851
#
#                                                                               2
# Date received                                                        2023-08-25
# Product                       Credit reporting or other personal consumer re...
# Sub-product                                                    Credit reporting
# Issue                                               Improper use of your report
# Sub-issue                     Credit inquiries on your report that you don't...
# Consumer complaint narrative                                                NaN
# Company public response                                                     NaN
# Company                                                           EQUIFAX, INC.
# State                                                                        FL
# ZIP code                                                                  32137
# Tags                                                                        NaN
# Consumer consent provided?                                                Other
# Submitted via                                                               Web
# Date sent to company                                                 2023-08-25
# Company response to consumer                            Closed with explanation
# Timely response?                                                            Yes
# Consumer disputed?                                                          NaN
# Complaint ID                                                            7560852

# %%
# Create a new dataframe with two columns
df1 = df[['Product', 'Consumer complaint narrative']].copy()

# Remove missing values
df1 = df1[pd.notnull(df1['Consumer complaint narrative'])]

# Renaming second column for a simpler name
df1.columns = ['Product', 'Consumer_complaint'] 

df1.shape
# Out:
# (1477894, 2)

# %%
df1.head()
# Out:
#                                                Product  \
# 14                         Checking or savings account
# 116                                           Mortgage
# 125  Credit reporting, credit repair services, or o...
# 126  Credit reporting, credit repair services, or o...
# 133  Credit reporting, credit repair services, or o...
#
#                                     Consumer_complaint
# 14   Citibank allowed debit card transactions to ov...
# 116  XXXX XXXX XXXX XXXX XXXX XXXX XXXX, Ohio XXXX ...
# 125  In accordance with the Fair Credit Reporting a...
# 126  On XX/XX/, 2023, XXXX XXXX admitted liability ...
# 133  XX/XX/XXXX ] [ XXXX XXXX XXXX ] [ XXXX XXXX XX...

# %%
# Percentage of complaints with text
total = df1['Consumer_complaint'].notnull().sum()
round((total/len(df)*100),1)
# Out:
# 36.2

# %%
pd.DataFrame(df.Product.unique()).values
# Out:
# array([['Credit reporting or other personal consumer reports'],
#        ['Credit reporting, credit repair services, or other personal consumer reports'],
#        ['Checking or savings account'],
#        ['Mortgage'],
#        ['Debt collection'],
#        ['Credit card'],
#        ['Student loan'],
#        ['Credit card or prepaid card'],
#        ['Vehicle loan or lease'],
#        ['Payday loan, title loan, personal loan, or advance loan'],
#        ['Money transfer, virtual currency, or money service'],
#        ['Prepaid card'],
#        ['Debt or credit management'],
#        ['Payday loan, title loan, or personal loan'],
#        ['Credit reporting'],
#        ['Bank account or service'],
#        ['Consumer Loan'],
#        ['Payday loan'],
#        ['Money transfers'],
#        ['Other financial service'],
#        ['Virtual currency']], dtype=object)

# %%
#the data was sampled
df2 = df1.sample(10000, random_state=1).copy()

# %%
# Renaming categories
df2.replace({'Product': 
             {'Credit reporting, credit repair services, or other personal consumer reports': 
              'Credit reporting, repair, or other', 
              'Credit reporting': 'Credit reporting, repair, or other',
             'Credit card': 'Credit card or prepaid card',
             'Prepaid card': 'Credit card or prepaid card',
             'Payday loan': 'Payday loan, title loan, or personal loan',
             'Money transfer': 'Money transfer, virtual currency, or money service',
             'Virtual currency': 'Money transfer, virtual currency, or money service'}}, 
            inplace= True)

# %%
pd.DataFrame(df2.Product.unique())
# Out:
#                                                     0
# 0                                            Mortgage
# 1                  Credit reporting, repair, or other
# 2                                     Debt collection
# 3                         Checking or savings account
# 4                             Bank account or service
# 5                         Credit card or prepaid card
# 6           Payday loan, title loan, or personal loan
# 7   Money transfer, virtual currency, or money ser...
# 8                               Vehicle loan or lease
# 9                                        Student loan
# 10                                      Consumer Loan
# 11                                    Money transfers
# 12                            Other financial service
# 13  Credit reporting or other personal consumer re...

# %%
y = df2['Product'] # Target or the labels we want to predict (i.e., the 13 different complaints of products)
data=y.value_counts().index
data
# Out:
# Index(['Credit reporting, repair, or other', 'Debt collection',
#        'Credit card or prepaid card', 'Mortgage',
#        'Checking or savings account', 'Student loan',
#        'Money transfer, virtual currency, or money service',
#        'Vehicle loan or lease', 'Payday loan, title loan, or personal loan',
#        'Bank account or service', 'Consumer Loan'],
#       dtype='object')

# %%
df2=df2[df2["Product"].isin(list(data[:11])) ]

# %%
# Create a new column 'category_id' with encoded categories 
df2['category_id'] = df2['Product'].factorize()[0]
category_id_df = df2[['Product', 'category_id']].drop_duplicates()


# Dictionaries for future use
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'Product']].values)

# New dataframe
df2.head()
# Out:
#                                     Product  \
# 1511706                            Mortgage
# 1191532  Credit reporting, repair, or other
# 1191375                     Debt collection
# 2535195  Credit reporting, repair, or other
# 2583742         Checking or savings account
#
#                                         Consumer_complaint  category_id
# 1511706  Paying extremely high PMI for 11 years on my m...            0
# 1191532  I am requesting again in regards to the inaccu...            1
# 1191375  Offices of XXXX and XXXX XXXX XXXX XXXX ( no s...            2
# 2535195  I submitted a letter to the 3 Credit Bureaus t...            1
# 2583742  This is Cashap stealing {$230.00} from my acco...            3

# %% [markdown]
# The bar chart below shows the number of complaints per category

# %%
fig = plt.figure(figsize=(8,6))
colors = ['grey','grey','grey','grey','grey','grey','grey','grey','grey',
    'grey','darkblue','darkblue','darkblue']
df2.groupby('Product').Consumer_complaint.count().sort_values().plot.barh(
    ylim=0, color=colors, title= 'NUMBER OF COMPLAINTS IN EACH PRODUCT CATEGORY\n')
plt.xlabel('Number of ocurrences', fontsize = 10);

# %%
y = df2['Product'] # Target or the labels we want to predict (i.e., the 13 different complaints of products)
data=y.value_counts().index
df2=df2[df2["Product"].isin(list(data[:11])) ]

# %% [markdown]
# # Text Preprocessing

# %%
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5,
                        ngram_range=(1, 2), 
                        stop_words='english')

# We transform each complaint into a vector
features = tfidf.fit_transform(df2.Consumer_complaint).toarray()

labels = df2.category_id

print("Each of the %d complaints is represented by %d features (TF-IDF score of unigrams and bigrams)" %(features.shape))
# Out:
# Each of the 9985 complaints is represented by 25967 features (TF-IDF score of unigrams and bigrams)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Finding the three most correlated terms with each of the product categories
N = 3
for Product, category_id in sorted(category_to_id.items()):
    features_chi2 = chi2(features, labels == category_id)
    indices = np.argsort(features_chi2[0])
    feature_names = np.array(tfidf.get_feature_names())[indices]
    unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
    bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
    print("\n==> %s:" %(Product))
    print("  * Most Correlated Unigrams are: %s" %(', '.join(unigrams[-N:])))
    print("  * Most Correlated Bigrams are: %s" %(', '.join(bigrams[-N:])))
# Out:
# ==> Bank account or service:
#   * Most Correlated Unigrams are: defect, deposit, citigold
#   * Most Correlated Bigrams are: number account, make deposit, xxxx overdraft
#
# ==> Checking or savings account:
#   * Most Correlated Unigrams are: checking, overdraft, bank
#   * Most Correlated Bigrams are: savings account, overdraft fees, checking account
#
# ==> Consumer Loan:
#   * Most Correlated Unigrams are: vehicle, dealership, car
#   * Most Correlated Bigrams are: 00 email, lease payment, lease payments
#
# ==> Credit card or prepaid card:
#   * Most Correlated Unigrams are: purchases, citi, card
#   * Most Correlated Bigrams are: use card, american express, credit card
#
# ==> Credit reporting, repair, or other:
#   * Most Correlated Unigrams are: 1681, section, reporting
#   * Most Correlated Bigrams are: credit report, 15 1681, 1681 section
#
# ==> Debt collection:
#   * Most Correlated Unigrams are: collect, collection, debt
#   * Most Correlated Bigrams are: trying collect, collection agency, collect debt
#
# ==> Money transfer, virtual currency, or money service:
#   * Most Correlated Unigrams are: venmo, paypal, coinbase
#   * Most Correlated Bigrams are: wire transfer, paypal account, cash app
#
# ==> Mortgage:
#   * Most Correlated Unigrams are: escrow, modification, mortgage
#   * Most Correlated Bigrams are: mortgage company, loan modification, mortgage payment
#
# ==> Payday loan, title loan, or personal loan:
#   * Most Correlated Unigrams are: avant, affirm, payday
#   * Most Correlated Bigrams are: saying verify, payday loans, payday loan
#
# ==> Student loan:
#   * Most Correlated Unigrams are: loans, student, navient
#   * Most Correlated Bigrams are: student loans, loan forgiveness, student loan
#
# ==> Vehicle loan or lease:
#   * Most Correlated Unigrams are: repossession, car, vehicle
#   * Most Correlated Bigrams are: bought car, vehicle repossessed, gm financial

# %% [markdown]
# # Multi-Classification models

# %% [markdown]
# The classification models evaluated are:

# %%
print("Random Forest\n",
"Linear Support Vector Machine\n",
"Multinomial Naive Bayes\n",
"Logistic Regression")
# Out:
# Random Forest
#  Linear Support Vector Machine
#  Multinomial Naive Bayes
#  Logistic Regression

# %%
#Spliting the data into train and test sets
y = df2['Product'] # Target or the labels we want to predict (i.e., the 13 different complaints of products)
data=y.value_counts().index
df2=df2[df2["Product"].isin(list(data[:11])) ]

# %%
X = df2['Consumer_complaint'] # Collection of documents
y = df2['Product'] # Target or the labels we want to predict (i.e., the 13 different complaints of products)

X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.32,
                                                    random_state = 0)

# %%
data=y.value_counts().index

# %%
df2=df2[df2["Product"].isin(list(data[:11])) ]

# %%
y_test.unique().shape
# Out:
# (11,)

# %%
df2.head()
#y_test.unique().shape
# Out:
#                                     Product  \
# 1511706                            Mortgage
# 1191532  Credit reporting, repair, or other
# 1191375                     Debt collection
# 2535195  Credit reporting, repair, or other
# 2583742         Checking or savings account
#
#                                         Consumer_complaint  category_id
# 1511706  Paying extremely high PMI for 11 years on my m...            0
# 1191532  I am requesting again in regards to the inaccu...            1
# 1191375  Offices of XXXX and XXXX XXXX XXXX XXXX ( no s...            2
# 2535195  I submitted a letter to the 3 Credit Bureaus t...            1
# 2583742  This is Cashap stealing {$230.00} from my acco...            3

# %% [markdown]
# # Models

# %%
models = [
    RandomForestClassifier(n_estimators=100, max_depth=5, random_state=0),
    LinearSVC(),
    MultinomialNB(),
    LogisticRegression(random_state=0),
]

# 5 Cross-validation
CV = 5
cv_df = pd.DataFrame(index=range(CV * len(models)))

entries = []
for model in models:
    model_name = model.__class__.__name__
    accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
    for fold_idx, accuracy in enumerate(accuracies):
        entries.append((model_name, fold_idx, accuracy))
    
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])

# %% [markdown]
# # Comparison of model performance

# %%
#The best mean acuracy was obtained with LinearSVC

# %%
cv_df.head()
# Out:
#                model_name  fold_idx  accuracy
# 0  RandomForestClassifier         0  0.551327
# 1  RandomForestClassifier         1  0.551327
# 2  RandomForestClassifier         2  0.550826
# 3  RandomForestClassifier         3  0.551327
# 4  RandomForestClassifier         4  0.551327

# %%
mean_accuracy = cv_df.groupby('model_name').accuracy.mean()
std_accuracy = cv_df.groupby('model_name').accuracy.std()

acc = pd.concat([mean_accuracy, std_accuracy], axis= 1, 
          ignore_index=True)
acc.columns = ['Mean Accuracy', 'Standard deviation']
acc
# Out:
#                         Mean Accuracy  Standard deviation
# model_name
# LinearSVC                    0.821332            0.008567
# LogisticRegression           0.802103            0.006407
# MultinomialNB                0.685829            0.005549
# RandomForestClassifier       0.551227            0.000224

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='model_name', y='accuracy', 
            data=cv_df, 
            color='lightblue', 
            showmeans=True)
plt.title("MEAN ACCURACY (cv = 5)\n", size=14);

# %%
y_train.unique().shape
# Out:
# (11,)

# %%
features.shape
# Out:
# (9985, 25967)

# %% [markdown]
# # Model Evaluation

# %%
X_train, X_test, y_train, y_test,indices_train,indices_test = train_test_split(features, 
                                                               labels, 
                                                               df2.index, test_size=0.25, 
                                                               random_state=1)
model = LinearSVC()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %% [markdown]
# # Precision, Recall, F1-score

# %%
# Classification report
print('\t\t\t\tCLASSIFICATIION METRICS\n')
print(metrics.classification_report(y_test, y_pred))#target_names= df2['Product'].unique()))
# Out:
# 				CLASSIFICATIION METRICS
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.95      0.90       167
#            1       0.88      0.94      0.91      1409
#            2       0.73      0.71      0.72       345
#            3       0.65      0.66      0.66       124
#            4       0.00      0.00      0.00        25
#            5       0.75      0.79      0.77       218
#            6       1.00      0.03      0.06        30
#            7       0.74      0.65      0.69        57
#            8       0.61      0.42      0.50        45
#            9       0.78      0.60      0.68        60
#           10       0.00      0.00      0.00        17
#
#     accuracy                           0.83      2497
#    macro avg       0.64      0.52      0.54      2497
# weighted avg       0.81      0.83      0.81      2497

# %% [markdown]
# # Confusion matrix

# %%
#A Confusion Matrix is a table which rows represent the actual class and columns represents the predicted class.

# %%
conf_mat = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(8,8))
sns.heatmap(conf_mat, annot=True, cmap="Blues", fmt='d',
            xticklabels=category_id_df.Product.values, 
            yticklabels=category_id_df.Product.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title("CONFUSION MATRIX - LinearSVC\n", size=16);

# %% [markdown]
# # Misclassified complaints

# %%
#Let’s have a look at the cases that were wrongly classified

# %%
conf_mat.shape
# Out:
# (11, 11)

# %%
category_id_df.category_id
# Out:
# 1511706     0
# 1191532     1
# 1191375     2
# 2583742     3
# 1578835     4
# 165252      5
# 1552905     6
# 279651      7
# 3744275     8
# 2596339     9
# 4019396    10
# Name: category_id, dtype: int64

# %%
for predicted in category_id_df.category_id:
    for actual in category_id_df.category_id:
        if predicted != actual and conf_mat[actual, predicted] >= 20:
            print("'{}' predicted as '{}' : {} examples.".format(id_to_category[actual], 
                                                           id_to_category[predicted], 
                                                           conf_mat[actual, predicted]))
    
            display(df2.loc[indices_test[(y_test == actual) & (y_pred == predicted)]][
# 1749090  Since nearly 60 years ago I've been harassed b...
# 2332099  I have contacted the creditor/company many tim...
# 3322124  No information given regarding account. Violat...
# 1144727  Mountain Run Solutions LLC has stole my inform...
# 518100   I am requesting for VALIDATION made pursuant t...
# 333164   Incorrect reporting of debt. Insurance at the ...
# 1149072  This is a collection for a vehicle that I surr...
# 263778   XXXX XXXX XXXX XXXX XXXX XXXX is still reporti...
# 635034   XXXX XXXX is trying to collect on behalf of XX...
# 2889308  I just checked my credit report to see that 01...
# 3722586  I wrote to all 3 companies about XXXX XXXX XXX...
# 1822346  As a federally protected XXXX, the consumer co...
# 1651718  NAR INC Never once contacted me. I have no ide...
# 1887820  I get phone calls and letter for a collection ...
# 760004   I have disputed a debt on my credit that is no...
# 1870836  I reached out serval times to get a payment ar...
# 555273   I recently received a copy of my credit report...
# 1177619  I recently received a letter dated XXXX XXXX, ...
# 3063752  I was laid off XX/XX/2011 and my last contact ...
# 873305   I, XXXX XXXX, have requested a debt verificati...
# 196080   AM Sher collection agency improperly report my...
# 1372844  I have filed a complaint with BCFP and The Att...
# 979393   Last year I discovered a false account with XX...
# 3023804  Walmart is reporting a debt on my credit file ...
# 1994471  The recently received a copy of my credit repo...
# 2629447  TO WHOM THIS MAY CONCERN I PREVIOUSLY DISPUTED...
# 3488201  Last year I discovered a false account with Di...
# 247676   I found this unrecognized account CHOICE RECOV...
# 3488234  I found that I was being sent to collections i...
# 1012161  Upon obtaining my credit report I notice a der...
# 661854   About 4 months ago i started receiving calls f...
# 2804325  Im not liable with XXXX. i do not have contact...
# 355250   XXXX, XXXX is a corporation. It is an incorpor...
# 1724121  I disputed XXXX ( XXXX XXXX ) in the amount of...
# 3215324  My name is XXXX XXXX, a federally protected co...
# 2559101  Under FCRA section 605 ( C ) Running of the re...
# 903839   In XX/XX/2016, my account with XXXX XXXX was c...
# 3460766  I have contacted Experian multiple times askin...
# 549457   I am XXXX XXXX XXXX, around XX/XX/2020. I exte...
# 1794610  There are accounts listed on my credit report ...
# 908291   Credit management reported XX/XX/2019 this is ...
# 30819    XXXX XXXX XXXX and national credit adjusters d...
# 634684                                       XXXX is unfit
# 3301809  I did not owe this debt and it does not belong...
# 413883   I have an unverified account from XXXX XXXX. I...
# 257201   Per tracking, tts been 2-3 months. No informat...
# 708532   On XX/XX/XXXX, I called the One Main Financial...
# 2877600  In XXXX XXXX 2017, I noticed a collection from...
# 3474122  According to the FCRA, I have the right to an ...
# 686148   This company has responded saying that they ha...
# 921252   Equifax is reporting collection account XXXX X...
# 1073216  There is an illegal collection which has conti...
# 438773   I am writing a complaint after being harassed ...

# %%
model.fit(features, labels)

N = 4
for Product, category_id in sorted(category_to_id.items()):
    indices = np.argsort(model.coef_[category_id])
    feature_names = np.array(tfidf.get_feature_names())[indices]
    unigrams = [v for v in reversed(feature_names) if len(v.split(' ')) == 1][:N]
    bigrams = [v for v in reversed(feature_names) if len(v.split(' ')) == 2][:N]
    print("\n==> '{}':".format(Product))
    print("  * Top unigrams: %s" %(', '.join(unigrams)))
    print("  * Top bigrams: %s" %(', '.join(bigrams)))
# Out:
# ==> 'Bank account or service':
#   * Top unigrams: bank, requirements, pin, deposit
#   * Top bigrams: number account, money taken, xxxx checks, xxxx overdraft
#
# ==> 'Checking or savings account':
#   * Top unigrams: bank, chime, overdraft, savings
#   * Top bigrams: pay bills, link account, debit card, savings account
#
# ==> 'Consumer Loan':
#   * Top unigrams: dealership, bmw, santander, car
#   * Top bigrams: tried pay, longer exists, reporting past, payment spoke
#
# ==> 'Credit card or prepaid card':
#   * Top unigrams: card, citi, visa, cards
#   * Top bigrams: credit limit, american express, information provided, balance transfer
#
# ==> 'Credit reporting, repair, or other':
#   * Top unigrams: experian, equifax, reporting, transunion
#   * Top bigrams: agency xxxx, auto loan, receive response, xxxx balance
#
# ==> 'Debt collection':
#   * Top unigrams: debt, collection, recovery, calling
#   * Top bigrams: trying collect, help remove, xxxx service, credit control
#
# ==> 'Money transfer, virtual currency, or money service':
#   * Top unigrams: coinbase, paypal, money, transfer
#   * Top bigrams: access xxxx, cash app, send money, chase bank
#
# ==> 'Mortgage':
#   * Top unigrams: mortgage, escrow, foreclosure, property
#   * Top bigrams: quicken loans, mortgage payments, mortgage payment, property tax
#
# ==> 'Payday loan, title loan, or personal loan':
#   * Top unigrams: loan, payday, club, affirm
#   * Top bigrams: loan told, late payment, payday loan, saying verify
#
# ==> 'Student loan':
#   * Top unigrams: navient, nelnet, fedloan, aes
#   * Top bigrams: attended xxxx, current account, loan forgiveness, leaving messages
#
# ==> 'Vehicle loan or lease':
#   * Top unigrams: car, vehicle, finance, auto
#   * Top bigrams: gm financial, vehicle repossessed, credit bank, fraudulent reporting

# %% [markdown]
# # Predictions

# %%
X.head()
# Out:
# 1511706    Paying extremely high PMI for 11 years on my m...
# 1191532    I am requesting again in regards to the inaccu...
# 1191375    Offices of XXXX and XXXX XXXX XXXX XXXX ( no s...
# 2535195    I submitted a letter to the 3 Credit Bureaus t...
# 2583742    This is Cashap stealing {$230.00} from my acco...
# Name: Consumer_complaint, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.25,
                                                    random_state = 0)

tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5,
                        ngram_range=(1, 2), 
                        stop_words='english')

fitted_vectorizer = tfidf.fit(X_train)
tfidf_vectorizer_vectors = fitted_vectorizer.transform(X_train)

model = LinearSVC().fit(tfidf_vectorizer_vectors, y_train)

# %%
#Let's see what is the classification that our model gives to this new complaint.

# %%
new_complaint = """Paying extremely high PMI for 11 years on my mortgage loan. I questioned the amount and have not been provided with any response as of XXXX/XXXX/XXXX. Also, Escrow amount seems excessive since XX/XX/XXXX and I am unable to reconcile what the increase is attributed to at this time."""
print(model.predict(fitted_vectorizer.transform([new_complaint])))
# Out:
# ['Mortgage']

# %%
#The algorithm has classified this text as a "Student loan" complaint. Now let's look at the real label of this complaint.

# %%
df2[df2['Consumer_complaint'] == new_complaint]
# Out:
#           Product                                 Consumer_complaint  \
# 1511706  Mortgage  Paying extremely high PMI for 11 years on my m...
#
#          category_id
# 1511706            0
